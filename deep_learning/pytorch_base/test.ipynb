# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, Dataset, TensorDataset # 数据加载器和数据集
import matplotlib.pyplot as plt

# %%
# 1.构建数据集
X = torch.randn(100, 1)
w = torch.tensor(2.5)
b = torch.tensor(5.2)
noise = torch.randn(100, 1) * 0.5
y = w * X + b + noise
print(X,X.shape)
print(y,y.shape)
# Out:
# tensor([[ 8.8807e-02],
#         [-9.5388e-01],
#         [ 1.3029e+00],
#         [-5.0203e-01],
#         [-9.4135e-01],
#         [-9.7193e-01],
#         [-4.4580e-03],
#         [ 6.8364e-01],
#         [ 6.2391e-01],
#         [ 1.1102e+00],
#         [-1.9776e+00],
#         [ 1.1656e+00],
#         [-5.1004e-01],
#         [ 3.2862e-01],
#         [ 1.6301e-03],
#         [-1.6897e+00],
#         [-6.5521e-01],
#         [-3.2613e-02],
#         [ 2.7070e-01],
#         [ 7.9910e-01],
#         [ 6.4527e-01],
#         [ 1.2342e+00],
#         [-1.3097e+00],
#         [-1.6128e+00],
#         [-2.6766e+00],
#         [-2.5012e-01],
#         [-3.1035e-01],
#         [ 6.8221e-01],
#         [-5.2348e-01],
#         [-3.3300e-01],
#         [-8.3263e-01],
#         [ 9.8311e-01],
#         [ 7.9301e-01],
#         [-2.4949e-01],
#         [ 4.5418e-01],
#         [ 2.3143e-01],
#         [ 7.8628e-01],
#         [-2.0775e+00],
#         [-3.9321e-01],
#         [ 4.5045e-01],
#         [-6.6836e-01],
#         [ 6.6111e-02],
#         [-1.3713e+00],
#         [-1.5324e+00],
#         [ 7.0717e-01],
#         [ 1.0660e+00],
#         [-4.6189e-01],
#         [ 8.2549e-01],
#         [ 8.7897e-01],
#         [-7.2214e-01],
#         [-1.3870e+00],
#         [ 9.6539e-01],
#         [ 6.9311e-01],
#         [ 8.2837e-01],
#         [ 8.5716e-01],
#         [-7.2473e-01],
#         [ 2.1636e-01],
#         [-5.7169e-01],
#         [-5.0456e-01],
#         [-7.6108e-01],
#         [ 1.2537e+00],
#         [-3.4958e-01],
#         [ 9.0307e-01],
#         [-5.0918e-01],
#         [-1.0405e+00],
#         [-2.0087e+00],
#         [ 9.4506e-01],
#         [-1.0294e+00],
#         [ 3.6966e-01],
#         [-2.2202e+00],
#         [ 9.9903e-01],
#         [-2.7173e-01],
#         [-8.1534e-01],
#         [-4.7213e-01],
#         [-4.8479e-01],
#         [-1.6373e-01],
#         [ 5.9455e-01],
#         [-2.6741e+00],
#         [-2.1639e+00],
#         [-1.1504e+00],
#         [ 1.4257e-01],
#         [-4.6493e-01],
#         [ 6.1162e-01],
#         [-9.7444e-01],
#         [-1.0354e+00],
#         [-1.7318e+00],
#         [ 4.1946e-01],
#         [-5.0607e-01],
#         [ 9.7354e-01],
#         [ 1.0439e+00],
#         [ 6.7345e-01],
#         [ 1.6510e-02],
#         [-7.0917e-02],
#         [ 1.3746e+00],
#         [-6.1110e-01],
#         [ 4.1023e-01],
#         [ 2.3824e-02],
#         [-4.6150e-01],
#         [-5.8793e-02],
#         [-1.3423e+00]]) torch.Size([100, 1])
# tensor([[ 4.9331],
#         [ 2.6311],
#         [ 8.3814],
#         [ 3.9290],
#         [ 2.6077],
#         [ 2.7200],
#         [ 6.1788],
#         [ 6.3285],
#         [ 8.1508],
#         [ 8.2036],
#         [ 0.3711],
#         [ 8.4873],
#         [ 3.8742],
#         [ 5.8345],
#         [ 5.1285],
#         [ 1.1786],
#         [ 3.4323],
#         [ 5.3408],
#         [ 6.2299],
#         [ 6.7944],
#         [ 7.2523],
#         [ 7.7778],
#         [ 2.6059],
#         [ 0.7736],
#         [-1.2073],
#         [ 5.0474],
#         [ 4.9881],
#         [ 7.7822],
#         [ 3.5942],
#         [ 3.5072],
#         [ 4.2405],
#         [ 8.0845],
#         [ 7.3612],
#         [ 4.1733],
#         [ 6.8456],
#         [ 5.9598],
#         [ 6.7861],
#         [-0.5191],
#         [ 4.0780],
#         [ 6.7282],
#         [ 3.4152],
#         [ 5.0175],
#         [ 2.0014],
#         [ 1.6678],
#         [ 7.1628],
#         [ 8.5239],
#         [ 4.3586],
#         [ 7.3323],
#         [ 7.8219],
#         [ 3.4806],
#         [ 2.0373],
#         [ 7.3678],
#         [ 6.5019],
#         [ 6.4828],
#         [ 7.5585],
#         [ 3.4114],
#         [ 6.0828],
#         [ 3.6614],
#         [ 3.6652],
#         [ 3.2362],
#         [ 7.7319],
#         [ 4.1465],
#         [ 6.3132],
#         [ 4.0331],
#         [ 2.6647],
#         [-0.1546],
#         [ 6.5396],
#         [ 2.9018],
#         [ 6.5063],
#         [-0.0796],
#         [ 7.4838],
#         [ 4.1713],
#         [ 3.2103],
#         [ 3.4649],
#         [ 3.8920],
#         [ 4.1969],
#         [ 6.9978],
#         [-0.9634],
#         [-1.0402],
#         [ 2.6257],
#         [ 5.4449],
#         [ 4.1975],
#         [ 7.2910],
#         [ 3.1858],
#         [ 2.4978],
#         [ 1.5838],
#         [ 6.1484],
#         [ 5.1793],
#         [ 8.2882],
#         [ 7.7167],
#         [ 7.8072],
#         [ 5.5435],
#         [ 5.4227],
#         [ 9.3933],
#         [ 3.4543],
#         [ 6.1424],
#         [ 5.6950],
#         [ 2.7827],
#         [ 5.1455],
#         [ 2.1895]]) torch.Size([100, 1])

# %%
plt.scatter(X,y)
plt.show()
